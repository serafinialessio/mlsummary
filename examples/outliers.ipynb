# %% [markdown]
# # Outliers detection

# %% [markdown]
# ## [Isolation forest](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html?highlight=isolationforest)

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.ensemble import IsolationForest
from mlsummary.outliers import IsolationForestSummary

iris = load_iris()
iris = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])
X = iris.drop(columns=['target'])
y = iris['target']
iforest = IsolationForest().fit(X)

# %%
iforest_summary = IsolationForestSummary(iforest, X = X)
iforest_summary.describe()
# Out:
# Isolation Forest algorithm
# ------------------
# Number of clusters: [-1  1]
# Contamination: -0.5
# Number of estimators: 100
# Estimator: ExtraTreeRegressor(max_depth=8, max_features=1)
# Max samples: auto
# Silhouette: 0.128
# Davies Bouldin: 10.972
# Calinski Harabasz: 0.947
# Clusters weights:
#   -1    1
#  38  112
# Clusters weights:
#         -1         1
#  0.253333  0.746667

# %%
iforest_summary.plot(X)

# %%
print(pd.DataFrame((iforest_summary.__dict__.keys()), columns = ['Attribute']))
# Out:
#           Attribute
# 0             model
# 1            labels
# 2        n_clusters
# 3         variables
# 4               SIL
# 5                DB
# 6                CH
# 7           centers
# 8      labels_names
# 9      cluster_size
# 10  cluster_weights
# 11              ARI
# 12               FM
# 13                X
# 14     n_estimators
# 15   base_estimator
# 16     max_features
# 17        bootstrap
# 18    contamination
# 19      max_samples

# %% [markdown]
# ## [One Class support vector machine](https://scikit-learn.org/stable/modules/generated/sklearn.svm.OneClassSVM.html)

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.svm import OneClassSVM
from mlsummary.outliers import OneClassSVMSummary

iris = load_iris()
iris = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])
X = iris.drop(columns=['target'])
y = iris['target']
ocSVM = OneClassSVM().fit(X)

# %%
ocSVM_summary = OneClassSVMSummary(ocSVM, X = X, store_X=True)
ocSVM_summary.describe()
# Out:
# One Class support vector machine algorithm
# ------------------
# Number of clusters: [-1  1]
# Kernel: rbf
# Regularization parameter: 0.0
# Kernel coefficient: scale
# Shrinking: True
# Number of support vectors:   0
#  76
# Silhouette: 0.133
# Davies Bouldin: 8.52
# Calinski Harabasz: 1.627
# Clusters weights:
#   -1   1
#  76  74
# Clusters weights:
#         -1         1
#  0.506667  0.493333

# %%
ocSVM_summary.plot()

# %%
print(pd.DataFrame((ocSVM_summary.__dict__.keys()), columns = ['Attribute']))
# Out:
#            Attribute
# 0              model
# 1             labels
# 2         n_clusters
# 3          variables
# 4                SIL
# 5                 DB
# 6                 CH
# 7            centers
# 8       labels_names
# 9       cluster_size
# 10   cluster_weights
# 11               ARI
# 12                FM
# 13                 X
# 14                 C
# 15            kernel
# 16            degree
# 17             gamma
# 18         shrinking
# 19  support_vectors_
# 20         n_support

# %% [markdown]
# ## [Local Outlier Factor](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.LocalOutlierFactor.html)

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.neighbors import LocalOutlierFactor
from mlsummary.outliers import LocalOutlierFactorSummary

iris = load_iris()
iris = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])
X = iris.drop(columns=['target'])
y = iris['target']
lof = LocalOutlierFactor().fit(X)

# %%
lof_summary = LocalOutlierFactorSummary(lof, X = X)
lof_summary.describe()
# Out:
# Local Outlier Factor algorithm
# ------------------
# Number of clusters: [-1  1]
# Metric: euclidean
# Radius: None
# Power Minkowski metric: 2
# Contamination: -1.5
# Algorithm: kd_tree
# Novelty detection: False
# Labels name: [-1  1]
# Silhouette: 0.246
# Davies Bouldin: 5.566
# Calinski Harabasz: 0.966
# Clusters weights:
#  -1    1
#  6  144
# Clusters weights:
#     -1     1
#  0.04  0.96

# %%
lof_summary.plot(X=X)

# %%
print(pd.DataFrame((lof_summary.__dict__.keys()), columns = ['Attribute']))
# Out:
#                   Attribute
# 0                     model
# 1                    labels
# 2                n_clusters
# 3                 variables
# 4                       SIL
# 5                        DB
# 6                        CH
# 7                   centers
# 8              labels_names
# 9              cluster_size
# 10          cluster_weights
# 11                      ARI
# 12                       FM
# 13                        X
# 14              labels_true
# 15              n_neighbors
# 16                   radius
# 17                   metric
# 18                        p
# 19               fit_method
# 20                leaf_size
# 21            contamination
# 22                  novelty
# 23  negative_outlier_factor
